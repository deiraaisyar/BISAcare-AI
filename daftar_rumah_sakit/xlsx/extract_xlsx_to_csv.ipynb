# %%
import pandas as pd
import os
import glob
from IPython.display import display

folder_path = "data" 

print(f"📁 Mengecek folder: {folder_path}")
print(f"Current working directory: {os.getcwd()}")

if os.path.exists(folder_path):
    print(f"✅ Folder ditemukan!")
    files_in_folder = os.listdir(folder_path)
    print(f"📄 Isi folder: {files_in_folder}")
else:
    print(f"❌ Folder tidak ditemukan: {folder_path}")

excel_files = glob.glob(os.path.join(folder_path, "*.xlsx")) + \
              glob.glob(os.path.join(folder_path, "*.xls"))

print(f"\n📁 Ditemukan {len(excel_files)} file Excel:")
for file in excel_files:
    print(f"   - {os.path.basename(file)}")

all_data = []

for file_path in excel_files:
    try:
        print(f"\n🔄 Membaca: {os.path.basename(file_path)}")
        
        df = pd.read_excel(file_path)
        
        df['Source_File'] = os.path.basename(file_path)
        
        all_data.append(df)
        print(f"   ✅ {df.shape[0]} baris, {df.shape[1]} kolom")
        
    except Exception as e:
        print(f"   ❌ Error: {str(e)}")

if all_data:
    combined_df = pd.concat(all_data, ignore_index=True)
    
    output_filename = "daftar_rumah_sakit_allianz.csv"
    combined_df.to_csv(output_filename, index=False, encoding='utf-8')
    
    print(f"\n✅ Berhasil menggabungkan {len(all_data)} file!")
    print(f"📊 Total: {combined_df.shape[0]} baris, {combined_df.shape[1]} kolom")
    print(f"💾 Tersimpan: {output_filename}")
    
    print(f"\n📊 Preview data gabungan:")
    display(combined_df.head())
    
    print(f"\n📋 Kolom yang tersedia:")
    for i, col in enumerate(combined_df.columns):
        print(f"   {i+1}. {col}")
    
    print(f"\n📁 Data per source file:")
    source_counts = combined_df['Source_File'].value_counts()
    for source_file, count in source_counts.items():
        print(f"   - {source_file}: {count} baris")
        
else:
    print("❌ Tidak ada data yang berhasil dibaca!")
# Out:
# 📁 Mengecek folder: data
# Current working directory: /home/lenovo/UGM/Lomba/COMPFEST/NLXOTI-AI/daftar_rumah_sakit/xlsx
# ✅ Folder ditemukan!
# 📄 Isi folder: ['daftar_Allianz Flexi Medical_10-08-2025.xlsx', 'daftar_Allianz Flexi Medical_10-08-2025 (1).xlsx', 'daftar_Allianz Flexi Medical_10-08-2025 (2).xlsx']
#
# 📁 Ditemukan 3 file Excel:
#    - daftar_Allianz Flexi Medical_10-08-2025.xlsx
#    - daftar_Allianz Flexi Medical_10-08-2025 (1).xlsx
#    - daftar_Allianz Flexi Medical_10-08-2025 (2).xlsx
#
# 🔄 Membaca: daftar_Allianz Flexi Medical_10-08-2025.xlsx
# /home/lenovo/anaconda3/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    ✅ 1150 baris, 18 kolom
#
# 🔄 Membaca: daftar_Allianz Flexi Medical_10-08-2025 (1).xlsx
# /home/lenovo/anaconda3/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    ✅ 3277 baris, 18 kolom
#
# 🔄 Membaca: daftar_Allianz Flexi Medical_10-08-2025 (2).xlsx
#    ✅ 23 baris, 18 kolom
#
# ✅ Berhasil menggabungkan 3 file!
# 📊 Total: 4450 baris, 20 kolom
# 💾 Tersimpan: daftar_rumah_sakit_allianz.csv
#
# 📊 Preview data gabungan:
# /home/lenovo/anaconda3/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#   Unnamed: 0  \
# 0        NaN
# 1         No
# 2          1
# 3          2
# 4          3
#
#   Daftar Jaringan untuk Asuransi Individu; Dalam Negeri; Allianz Flexi Medical; Cashless; Semua Provinsi; Semua Kota;  \
# 0                                08-10-2025 07:13 AM
# 1                                      Nama Jaringan
# 2                              AWAL BROS A. YANI, RS
# 3                                AWAL BROS BATAM, RS
# 4                                AWAL BROS DUMAI, RS
#
#                                        Unnamed: 2         Unnamed: 3  \
# 0  Daftar Rumah Sakit bisa berubah sewaktu-waktu.                NaN
# 1                                Penyedia Layanan  Individu/Kumpulan
# 2                          Global Excel Indonesia           Individu
# 3                          Global Excel Indonesia           Individu
# 4                          Global Excel Indonesia           Individu
#
#    Unnamed: 4      Unnamed: 5 Unnamed: 6      Unnamed: 7      Unnamed: 8  \
# 0         NaN             NaN        NaN             NaN             NaN
# 1  Cara Bayar  Lokasi (DN/LN)     Negara        Provinsi            Kota
# 2    Cashless    Dalam Negeri  INDONESIA            RIAU  KOTA PEKANBARU
# 3    Cashless    Dalam Negeri  INDONESIA  KEPULAUAN RIAU      KOTA BATAM
# 4    Cashless    Dalam Negeri  INDONESIA            RIAU      KOTA DUMAI
#
#       Unnamed: 9                      Unnamed: 10 Unnamed: 11  Unnamed: 12  \
# 0            NaN                              NaN         NaN          NaN
# 1           Telp                           Alamat  Rawat Inap  Rawat Jalan
# 2    (0761)21000  JL JEND A YANI NO 73, PEKANBARU          YA           YA
# 3   (0778)431777     JL. GAJAH MADA KAV. 1, BATAM          YA           YA
# 4  (0765)5901888    JL JEND SUDIRMAN NO 88, DUMAI          YA           YA
#
#   Unnamed: 13 Unnamed: 14                     Unnamed: 15  \
# 0         NaN         NaN                             NaN
# 1  Rawat Gigi       Optik  Kategori (RS/Klinik/Lab/Optik)
# 2           -          YA                     Rumah Sakit
# 3           -          YA                     Rumah Sakit
# 4          YA          YA                     Rumah Sakit
#
#                                          Unnamed: 16  \
# 0                                                NaN
# 1                                         Keterangan
# 2  TANGGAL BERGABUNG MENJADI ALLIANZ BLUE EAGLE N...
# 3  TANGGAL BERGABUNG MENJADI ALLIANZ BLUE EAGLE N...
# 4  TANGGAL BERGABUNG MENJADI ALLIANZ BLUE EAGLE N...
#
#                                     Source_File  \
# 0  daftar_Allianz Flexi Medical_10-08-2025.xlsx
# 1  daftar_Allianz Flexi Medical_10-08-2025.xlsx
# 2  daftar_Allianz Flexi Medical_10-08-2025.xlsx
# 3  daftar_Allianz Flexi Medical_10-08-2025.xlsx
# 4  daftar_Allianz Flexi Medical_10-08-2025.xlsx
#
#   Daftar Jaringan untuk Asuransi Individu; Dalam Negeri; Allianz Flexi Medical; Reimbursement; Semua Provinsi; Semua Kota;  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Daftar Jaringan untuk Asuransi Individu; Dalam Negeri; Allianz Flexi Medical; Diluar Cakupan Pertanggungan/Perlindungan; Semua Provinsi; Semua Kota;
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 📋 Kolom yang tersedia:
#    1. Unnamed: 0
#    2. Daftar Jaringan untuk Asuransi Individu; Dalam Negeri; Allianz Flexi Medical; Cashless; Semua Provinsi; Semua Kota;
#    3. Unnamed: 2
#    4. Unnamed: 3
#    5. Unnamed: 4
#    6. Unnamed: 5
#    7. Unnamed: 6
#    8. Unnamed: 7
#    9. Unnamed: 8
#    10. Unnamed: 9
#    11. Unnamed: 10
#    12. Unnamed: 11
#    13. Unnamed: 12
#    14. Unnamed: 13
#    15. Unnamed: 14
#    16. Unnamed: 15
#    17. Unnamed: 16
#    18. Source_File
#    19. Daftar Jaringan untuk Asuransi Individu; Dalam Negeri; Allianz Flexi Medical; Reimbursement; Semua Provinsi; Semua Kota;
#    20. Daftar Jaringan untuk Asuransi Individu; Dalam Negeri; Allianz Flexi Medical; Diluar Cakupan Pertanggungan/Perlindungan; Semua Provinsi; Semua Kota;
#
# 📁 Data per source file:
#    - daftar_Allianz Flexi Medical_10-08-2025 (1).xlsx: 3277 baris
#    - daftar_Allianz Flexi Medical_10-08-2025.xlsx: 1150 baris
#    - daftar_Allianz Flexi Medical_10-08-2025 (2).xlsx: 23 baris

# %%
import pandas as pd

df = pd.read_csv('daftar_rumah_sakit_allianz.csv')
df
# Out:
#      Unnamed: 0  \
# 0           NaN
# 1            No
# 2             1
# 3             2
# 4             3
# ...         ...
# 4445         17
# 4446         18
# 4447         19
# 4448         20
# 4449         21
#
#      Daftar Jaringan untuk Asuransi Individu; Dalam Negeri; Allianz Flexi Medical; Cashless; Semua Provinsi; Semua Kota;  \
# 0                                   08-10-2025 07:13 AM
# 1                                         Nama Jaringan
# 2                                 AWAL BROS A. YANI, RS
# 3                                   AWAL BROS BATAM, RS
# 4                                   AWAL BROS DUMAI, RS
# ...                                                 ...
# 4445                                                NaN
# 4446                                                NaN
# 4447                                                NaN
# 4448                                                NaN
# 4449                                                NaN
#
#                                           Unnamed: 2         Unnamed: 3  \
# 0     Daftar Rumah Sakit bisa berubah sewaktu-waktu.                NaN
# 1                                   Penyedia Layanan  Individu/Kumpulan
# 2                             Global Excel Indonesia           Individu
# 3                             Global Excel Indonesia           Individu
# 4                             Global Excel Indonesia           Individu
# ...                                              ...                ...
# 4445                          Global Excel Indonesia           Individu
# 4446                          Global Excel Indonesia           Individu
# 4447                          Global Excel Indonesia           Individu
# 4448                          Global Excel Indonesia           Individu
# 4449                          Global Excel Indonesia           Individu
#
#                                      Unnamed: 4      Unnamed: 5 Unnamed: 6  \
# 0                                           NaN             NaN        NaN
# 1                                    Cara Bayar  Lokasi (DN/LN)     Negara
# 2                                      Cashless    Dalam Negeri  INDONESIA
# 3                                      Cashless    Dalam Negeri  INDONESIA
# 4                                      Cashless    Dalam Negeri  INDONESIA
# ...                                         ...             ...        ...
# 4445  Diluar Cakupan Pertanggungan/Perlindungan    Dalam Negeri  INDONESIA
# 4446  Diluar Cakupan Pertanggungan/Perlindungan    Dalam Negeri  INDONESIA
# 4447  Diluar Cakupan Pertanggungan/Perlindungan    Dalam Negeri  INDONESIA
# 4448  Diluar Cakupan Pertanggungan/Perlindungan    Dalam Negeri  INDONESIA
# 4449  Diluar Cakupan Pertanggungan/Perlindungan    Dalam Negeri  INDONESIA
#
#           Unnamed: 7            Unnamed: 8     Unnamed: 9  \
# 0                NaN                   NaN            NaN
# 1           Provinsi                  Kota           Telp
# 2               RIAU        KOTA PEKANBARU    (0761)21000
# 3     KEPULAUAN RIAU            KOTA BATAM   (0778)431777
# 4               RIAU            KOTA DUMAI  (0765)5901888
# ...              ...                   ...            ...
# 4445      JAWA BARAT      KABUPATEN BEKASI            NaN
# 4446  SUMATERA UTARA            KOTA MEDAN            NaN
# 4447            RIAU  KABUPATEN ROKAN HULU            NaN
# 4448  SUMATERA UTARA            KOTA MEDAN            NaN
# 4449            ACEH      KOTA LHOKSEUMAWE            NaN
#
#                                             Unnamed: 10 Unnamed: 11  \
# 0                                                   NaN         NaN
# 1                                                Alamat  Rawat Inap
# 2                       JL JEND A YANI NO 73, PEKANBARU          YA
# 3                          JL. GAJAH MADA KAV. 1, BATAM          YA
# 4                         JL JEND SUDIRMAN NO 88, DUMAI          YA
# ...                                                 ...         ...
# 4445  JL. RAYA IMAM BONJOL NO.7, CIBITUNG, CIKARANG ...          YA
# 4446                               JL MENTENG VII NO 62          YA
# 4447  JL SULTAN ZAINAL ABIDINSYAH, RANTAU KASAI TEMB...          YA
# 4448                           JL RING ROAD/GAGAK HITAM          YA
# 4449  JL. SAMUDRA NO.53A KP JAWA KEC. BANDA SAKTI KO...          YA
#
#       Unnamed: 12 Unnamed: 13 Unnamed: 14                     Unnamed: 15  \
# 0             NaN         NaN         NaN                             NaN
# 1     Rawat Jalan  Rawat Gigi       Optik  Kategori (RS/Klinik/Lab/Optik)
# 2              YA           -          YA                     Rumah Sakit
# 3              YA           -          YA                     Rumah Sakit
# 4              YA          YA          YA                     Rumah Sakit
# ...           ...         ...         ...                             ...
# 4445           YA          YA          YA                     Rumah Sakit
# 4446           YA          YA          YA                     Rumah Sakit
# 4447           YA          YA          YA                     Rumah Sakit
# 4448           YA          YA          YA                     Rumah Sakit
# 4449           YA          YA          YA                     Rumah Sakit
#
#                                             Unnamed: 16  \
# 0                                                   NaN
# 1                                            Keterangan
# 2     TANGGAL BERGABUNG MENJADI ALLIANZ BLUE EAGLE N...
# 3     TANGGAL BERGABUNG MENJADI ALLIANZ BLUE EAGLE N...
# 4     TANGGAL BERGABUNG MENJADI ALLIANZ BLUE EAGLE N...
# ...                                                 ...
# 4445  BERLAKU UNTUK PRODUK : HOSPITAL & SURGICAL CAR...
# 4446  BERLAKU UNTUK PRODUK : HOSPITAL & SURGICAL CAR...
# 4447  BERLAKU UNTUK PRODUK : HOSPITAL & SURGICAL CAR...
# 4448  BERLAKU UNTUK PRODUK : HOSPITAL & SURGICAL CAR...
# 4449  BERLAKU UNTUK PRODUK : HOSPITAL & SURGICAL CAR...
#
#                                            Source_File  \
# 0         daftar_Allianz Flexi Medical_10-08-2025.xlsx
# 1         daftar_Allianz Flexi Medical_10-08-2025.xlsx
# 2         daftar_Allianz Flexi Medical_10-08-2025.xlsx
# 3         daftar_Allianz Flexi Medical_10-08-2025.xlsx
# 4         daftar_Allianz Flexi Medical_10-08-2025.xlsx
# ...                                                ...
# 4445  daftar_Allianz Flexi Medical_10-08-2025 (2).xlsx
# 4446  daftar_Allianz Flexi Medical_10-08-2025 (2).xlsx
# 4447  daftar_Allianz Flexi Medical_10-08-2025 (2).xlsx
# 4448  daftar_Allianz Flexi Medical_10-08-2025 (2).xlsx
# 4449  daftar_Allianz Flexi Medical_10-08-2025 (2).xlsx
#
#      Daftar Jaringan untuk Asuransi Individu; Dalam Negeri; Allianz Flexi Medical; Reimbursement; Semua Provinsi; Semua Kota;  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4445                                                NaN
# 4446                                                NaN
# 4447                                                NaN
# 4448                                                NaN
# 4449                                                NaN
#
#      Daftar Jaringan untuk Asuransi Individu; Dalam Negeri; Allianz Flexi Medical; Diluar Cakupan Pertanggungan/Perlindungan; Semua Provinsi; Semua Kota;
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4445                                  RIDHOKA SALMA, RS
# 4446                                          RIDOS, RS
# 4447                                TAMBUSAI MEDIKA, RS
# 4448                                 TERE MARGARETH, RS
# 4449                              TK IV LHOKSEUMAWE, RS
#
# [4450 rows x 20 columns]

# %%
df.drop(columns=['Unnamed: 0', 'Daftar Jaringan untuk Asuransi Individu; Dalam Negeri; Allianz Flexi Medical; Diluar Cakupan Pertanggungan/Perlindungan; Semua Provinsi; Semua Kota;',
                 'Daftar Jaringan untuk Asuransi Individu; Dalam Negeri; Allianz Flexi Medical; Reimbursement; Semua Provinsi; Semua Kota;', 'Source_File', 'Unnamed: 5', 'Unnamed: 6',
                 'Unnamed: 15', 'Unnamed: 16'], inplace=True)

# %%
df = df[~df.apply(lambda row: row.astype(str).str.contains("Nama Jaringan", case=False, na=False).any(), axis=1)]
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1146 entries, 2 to 1149
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Nama_Jaringan      1146 non-null   object
#  1   Penyedia_Layanan   1146 non-null   object
#  2   Individu_Kumpulan  1146 non-null   object
#  3   Cara_Bayar         1146 non-null   object
#  4   Provinsi           1146 non-null   object
#  5   Kota               1146 non-null   object
#  6   Telp               1146 non-null   object
#  7   Alamat             1146 non-null   object
#  8   Rawat_Inap         1146 non-null   object
#  9   Rawat_Jalan        1146 non-null   object
#  10  Rawat_Gigi         1146 non-null   object
#  11  Optik              1146 non-null   object
# dtypes: object(12)
# memory usage: 116.4+ KB

# %%
# Ganti nama kolom sesuai yang diminta
df.columns = [
    'Nama_Jaringan',           # 0
    'Penyedia_Layanan',        # 1 (Unnamed: 2)
    'Individu_Kumpulan',       # 2 (Unnamed: 3)
    'Cara_Bayar',              # 3 (Unnamed: 4)
    'Provinsi',                # 4 (Unnamed: 7)
    'Kota',                    # 5 (Unnamed: 8)
    'Telp',                    # 6 (Unnamed: 9)
    'Alamat',                  # 7 (Unnamed: 10)
    'Rawat_Inap',              # 8 (Unnamed: 11)
    'Rawat_Jalan',             # 9 (Unnamed: 12)
    'Rawat_Gigi',              # 10 (Unnamed: 13)
    'Optik'                    # 11 (Unnamed: 14)
]

print("✅ Nama kolom berhasil diganti!")
print(f"📋 Kolom baru: {list(df.columns)}")

# Lihat preview data dengan nama kolom baru
df.head()
# Out:
# ✅ Nama kolom berhasil diganti!
# 📋 Kolom baru: ['Nama_Jaringan', 'Penyedia_Layanan', 'Individu_Kumpulan', 'Cara_Bayar', 'Provinsi', 'Kota', 'Telp', 'Alamat', 'Rawat_Inap', 'Rawat_Jalan', 'Rawat_Gigi', 'Optik']
#              Nama_Jaringan        Penyedia_Layanan Individu_Kumpulan  \
# 2    AWAL BROS A. YANI, RS  Global Excel Indonesia          Individu
# 3      AWAL BROS BATAM, RS  Global Excel Indonesia          Individu
# 4      AWAL BROS DUMAI, RS  Global Excel Indonesia          Individu
# 5      AWAL BROS PANAM, RS  Global Excel Indonesia          Individu
# 6  AWAL BROS PEKANBARU, RS  Global Excel Indonesia          Individu
#
#   Cara_Bayar        Provinsi            Kota           Telp  \
# 2   Cashless            RIAU  KOTA PEKANBARU    (0761)21000
# 3   Cashless  KEPULAUAN RIAU      KOTA BATAM   (0778)431777
# 4   Cashless            RIAU      KOTA DUMAI  (0765)5901888
# 5   Cashless            RIAU  KOTA PEKANBARU   (0761)586111
# 6   Cashless            RIAU  KOTA PEKANBARU    (0761)47333
#
#                                        Alamat Rawat_Inap Rawat_Jalan  \
# 2             JL JEND A YANI NO 73, PEKANBARU         YA          YA
# 3                JL. GAJAH MADA KAV. 1, BATAM         YA          YA
# 4               JL JEND SUDIRMAN NO 88, DUMAI         YA          YA
# 5  JL. HR. SOEBRANTAS NO.88, PANAM, PEKANBARU         YA          YA
# 6        JL. JEND. SUDIRMAN NO.117, PEKANBARU         YA          YA
#
#   Rawat_Gigi Optik
# 2          -    YA
# 3          -    YA
# 4         YA    YA
# 5          -    YA
# 6          -    YA

# %%
df['Rawat_Inap'] = df['Rawat_Inap'].astype(str).str.replace('(?i)^ya$', 'Rawat_Inap', regex=True)
df['Rawat_Jalan'] = df['Rawat_Jalan'].astype(str).str.replace('(?i)^ya$', 'Rawat_Jalan', regex=True)
df['Rawat_Gigi'] = df['Rawat_Gigi'].astype(str).str.replace('(?i)^ya$', 'Rawat_Gigi', regex=True)
df['Optik'] = df['Optik'].astype(str).str.replace('(?i)^ya$', 'Optik', regex=True)

df
# Out:
#                    Nama_Jaringan        Penyedia_Layanan Individu_Kumpulan  \
# 2          AWAL BROS A. YANI, RS  Global Excel Indonesia          Individu
# 3            AWAL BROS BATAM, RS  Global Excel Indonesia          Individu
# 4            AWAL BROS DUMAI, RS  Global Excel Indonesia          Individu
# 5            AWAL BROS PANAM, RS  Global Excel Indonesia          Individu
# 6        AWAL BROS PEKANBARU, RS  Global Excel Indonesia          Individu
# ...                          ...                     ...               ...
# 1145     YADIKA PONDOK BAMBU, RS  Global Excel Indonesia          Individu
# 1146  YPK MENARA MANDIRI, KLINIK  Global Excel Indonesia          Individu
# 1147              ZAFIRA, KLINIK  Global Excel Indonesia          Individu
# 1148                 ZAHIRAH, RS  Global Excel Indonesia          Individu
# 1149      ZAINAB PEKANBARU, RSIA  Global Excel Indonesia          Individu
#
#      Cara_Bayar        Provinsi                  Kota           Telp  \
# 2      Cashless            RIAU        KOTA PEKANBARU    (0761)21000
# 3      Cashless  KEPULAUAN RIAU            KOTA BATAM   (0778)431777
# 4      Cashless            RIAU            KOTA DUMAI  (0765)5901888
# 5      Cashless            RIAU        KOTA PEKANBARU   (0761)586111
# 6      Cashless            RIAU        KOTA PEKANBARU    (0761)47333
# ...         ...             ...                   ...            ...
# 1145   Cashless     DKI JAKARTA    KOTA JAKARTA TIMUR   (021)8615754
# 1146   Cashless     DKI JAKARTA  KOTA JAKARTA SELATAN   (021)3909725
# 1147   Cashless     DKI JAKARTA    KOTA JAKARTA TIMUR  (021)85911686
# 1148   Cashless     DKI JAKARTA  KOTA JAKARTA SELATAN   (021)7872210
# 1149   Cashless            RIAU        KOTA PEKANBARU    (076)124000
#
#                                                  Alamat  Rawat_Inap  \
# 2                       JL JEND A YANI NO 73, PEKANBARU  Rawat_Inap
# 3                          JL. GAJAH MADA KAV. 1, BATAM  Rawat_Inap
# 4                         JL JEND SUDIRMAN NO 88, DUMAI  Rawat_Inap
# 5            JL. HR. SOEBRANTAS NO.88, PANAM, PEKANBARU  Rawat_Inap
# 6                  JL. JEND. SUDIRMAN NO.117, PEKANBARU  Rawat_Inap
# ...                                                 ...         ...
# 1145  JL PAHLAWAN REVOLUSI NO 47, PONDOK BAMBU, JAKA...  Rawat_Inap
# 1146  MENARA 2 LT. 3, MENARA MANDIRI, JL. JEND SUDIR...           -
# 1147  JL KAYUMANIS TIMUR NO 37, RT 014/002 KAYUMANIS...           -
# 1148        JL. SIRSAK NO.21 JAGAKARSA, JAKARTA SELATAN  Rawat_Inap
# 1149         JL.RONGGOWARSITO I NO.1 ,      , PEKANBARU  Rawat_Inap
#
#       Rawat_Jalan  Rawat_Gigi  Optik
# 2     Rawat_Jalan           -  Optik
# 3     Rawat_Jalan           -  Optik
# 4     Rawat_Jalan  Rawat_Gigi  Optik
# 5     Rawat_Jalan           -  Optik
# 6     Rawat_Jalan           -  Optik
# ...           ...         ...    ...
# 1145  Rawat_Jalan           -  Optik
# 1146  Rawat_Jalan  Rawat_Gigi  Optik
# 1147  Rawat_Jalan           -  Optik
# 1148  Rawat_Jalan           -  Optik
# 1149  Rawat_Jalan  Rawat_Gigi  Optik
#
# [1146 rows x 12 columns]

# %%
# Rename kolom utama
df = df.rename(columns={'Nama_Jaringan': 'nama_rumah_sakit', 'Alamat': 'alamat', 'Telp': 'telp'})

# Kolom yang akan digabungkan ke Text (kecuali nama_rumah_sakit, alamat, telp)
columns_to_text = [col for col in df.columns if col not in ['nama_rumah_sakit', 'alamat', 'telp']]

print(f"🔄 Menggabungkan kolom ke Text: {columns_to_text}")

# Fungsi untuk membuat kolom Text yang bersih
def create_clean_text(row):
    """Buat text dari kolom yang dipilih dengan format yang rapi"""
    text_parts = []
    
    for col in columns_to_text:
        value = str(row[col]).strip()
        if value and value != 'nan' and value != 'None' and value != '':
            text_parts.append(value)
    
    return ' | '.join(text_parts)

# Apply fungsi ke setiap baris
df['Text'] = df.apply(create_clean_text, axis=1)

# Bersihkan kolom alamat dan telp dari nilai nan
df['alamat'] = df['alamat'].fillna('').astype(str).str.strip()
df['telp'] = df['telp'].fillna('').astype(str).str.strip()

# Replace 'nan' string dengan empty string
df['alamat'] = df['alamat'].replace('nan', '')
df['telp'] = df['telp'].replace('nan', '')

# Pilih kolom final
result_df = df[['nama_rumah_sakit', 'alamat', 'telp', 'Text']].copy()

# Simpan hasil
result_df.to_csv('daftar_rumah_sakit_allianz_fixed.csv', index=False, encoding='utf-8')
print(f"\n💾 Data tersimpan: daftar_rumah_sakit_allianz_fixed.csv")

result_df
# Out:
# 🔄 Menggabungkan kolom ke Text: ['Penyedia_Layanan', 'Individu_Kumpulan', 'Cara_Bayar', 'Provinsi', 'Kota', 'Rawat_Inap', 'Rawat_Jalan', 'Rawat_Gigi', 'Optik', 'Text']
#
# 💾 Data tersimpan: daftar_rumah_sakit_allianz_fixed.csv
#                nama_rumah_sakit  \
# 2          RS AWAL BROS A. YANI
# 3            RS AWAL BROS BATAM
# 4            RS AWAL BROS DUMAI
# 5            RS AWAL BROS PANAM
# 6        RS AWAL BROS PEKANBARU
# ...                         ...
# 1145     RS YADIKA PONDOK BAMBU
# 1146  KLINIK YPK MENARA MANDIRI
# 1147              KLINIK ZAFIRA
# 1148                 RS ZAHIRAH
# 1149      RSIA ZAINAB PEKANBARU
#
#                                                  alamat           telp  \
# 2                       JL JEND A YANI NO 73, PEKANBARU    (0761)21000
# 3                          JL. GAJAH MADA KAV. 1, BATAM   (0778)431777
# 4                         JL JEND SUDIRMAN NO 88, DUMAI  (0765)5901888
# 5            JL. HR. SOEBRANTAS NO.88, PANAM, PEKANBARU   (0761)586111
# 6                  JL. JEND. SUDIRMAN NO.117, PEKANBARU    (0761)47333
# ...                                                 ...            ...
# 1145  JL PAHLAWAN REVOLUSI NO 47, PONDOK BAMBU, JAKA...   (021)8615754
# 1146  MENARA 2 LT. 3, MENARA MANDIRI, JL. JEND SUDIR...   (021)3909725
# 1147  JL KAYUMANIS TIMUR NO 37, RT 014/002 KAYUMANIS...  (021)85911686
# 1148        JL. SIRSAK NO.21 JAGAKARSA, JAKARTA SELATAN   (021)7872210
# 1149         JL.RONGGOWARSITO I NO.1 ,      , PEKANBARU    (076)124000
#
#                                                    Text
# 2     Global Excel Indonesia | Individu | Cashless |...
# 3     Global Excel Indonesia | Individu | Cashless |...
# 4     Global Excel Indonesia | Individu | Cashless |...
# 5     Global Excel Indonesia | Individu | Cashless |...
# 6     Global Excel Indonesia | Individu | Cashless |...
# ...                                                 ...
# 1145  Global Excel Indonesia | Individu | Cashless |...
# 1146  Global Excel Indonesia | Individu | Cashless |...
# 1147  Global Excel Indonesia | Individu | Cashless |...
# 1148  Global Excel Indonesia | Individu | Cashless |...
# 1149  Global Excel Indonesia | Individu | Cashless |...
#
# [1146 rows x 4 columns]

# %%
import re

def move_suffix_to_prefix(name):
    """
    Jika nama mengandung koma, pindahkan kata setelah koma ke depan.
    Contoh: 'AWAL BROS BATAM, RS' -> 'RS AWAL BROS BATAM'
    """
    if pd.isna(name) or str(name).strip() == '':
        return name
    name = str(name).strip()
    # Cek pola: ada koma, lalu kata (tanpa koma lagi)
    match = re.match(r'^(.*?),\s*([A-Za-z0-9 ]+)$', name)
    if match:
        main = match.group(1).strip()
        suffix = match.group(2).strip()
        return f"{suffix} {main}"
    return name

# Terapkan ke kolom nama_rumah_sakit
result_df['nama_rumah_sakit'] = result_df['nama_rumah_sakit'].apply(move_suffix_to_prefix)

# Lanjutkan proses seperti sebelumnya
columns_to_text = [col for col in result_df.columns if col not in ['nama_rumah_sakit', 'alamat', 'telp']]

def create_clean_text(row):
    text_parts = []
    for col in columns_to_text:
        value = str(row[col]).strip()
        if value and value != 'nan' and value != 'None' and value != '':
            text_parts.append(value)
    return ' | '.join(text_parts)

result_df['Text'] = result_df.apply(create_clean_text, axis=1)
result_df['alamat'] = result_df['alamat'].fillna('').astype(str).str.strip().replace('nan', '')
result_df['telp'] = result_df['telp'].fillna('').astype(str).str.strip().replace('nan', '')

result_df = result_df[['nama_rumah_sakit', 'alamat', 'telp', 'Text']].copy()
result_df.to_csv('daftar_rumah_sakit_allianz_fixed.csv', index=False, encoding='utf-8')
print("\n💾 Data tersimpan: daftar_rumah_sakit_allianz_fixed.csv")

result_df
# Out:
# 💾 Data tersimpan: daftar_rumah_sakit_allianz_fixed.csv
#                nama_rumah_sakit  \
# 2          RS AWAL BROS A. YANI
# 3            RS AWAL BROS BATAM
# 4            RS AWAL BROS DUMAI
# 5            RS AWAL BROS PANAM
# 6        RS AWAL BROS PEKANBARU
# ...                         ...
# 1145     RS YADIKA PONDOK BAMBU
# 1146  KLINIK YPK MENARA MANDIRI
# 1147              KLINIK ZAFIRA
# 1148                 RS ZAHIRAH
# 1149      RSIA ZAINAB PEKANBARU
#
#                                                  alamat           telp  \
# 2                       JL JEND A YANI NO 73, PEKANBARU    (0761)21000
# 3                          JL. GAJAH MADA KAV. 1, BATAM   (0778)431777
# 4                         JL JEND SUDIRMAN NO 88, DUMAI  (0765)5901888
# 5            JL. HR. SOEBRANTAS NO.88, PANAM, PEKANBARU   (0761)586111
# 6                  JL. JEND. SUDIRMAN NO.117, PEKANBARU    (0761)47333
# ...                                                 ...            ...
# 1145  JL PAHLAWAN REVOLUSI NO 47, PONDOK BAMBU, JAKA...   (021)8615754
# 1146  MENARA 2 LT. 3, MENARA MANDIRI, JL. JEND SUDIR...   (021)3909725
# 1147  JL KAYUMANIS TIMUR NO 37, RT 014/002 KAYUMANIS...  (021)85911686
# 1148        JL. SIRSAK NO.21 JAGAKARSA, JAKARTA SELATAN   (021)7872210
# 1149         JL.RONGGOWARSITO I NO.1 ,      , PEKANBARU    (076)124000
#
#                                                    Text
# 2     Global Excel Indonesia | Individu | Cashless |...
# 3     Global Excel Indonesia | Individu | Cashless |...
# 4     Global Excel Indonesia | Individu | Cashless |...
# 5     Global Excel Indonesia | Individu | Cashless |...
# 6     Global Excel Indonesia | Individu | Cashless |...
# ...                                                 ...
# 1145  Global Excel Indonesia | Individu | Cashless |...
# 1146  Global Excel Indonesia | Individu | Cashless |...
# 1147  Global Excel Indonesia | Individu | Cashless |...
# 1148  Global Excel Indonesia | Individu | Cashless |...
# 1149  Global Excel Indonesia | Individu | Cashless |...
#
# [1146 rows x 4 columns]

# %%
# Pilih kolom final
result_df = df[['nama_rumah_sakit', 'alamat', 'telp', 'Text']].copy()

# Ganti nama kolom 'Text' menjadi 'text'
result_df = result_df.rename(columns={'Text': 'text'})

# Simpan hasil
result_df.to_csv('daftar_rumah_sakit_allianz_fixed.csv', index=False, encoding='utf-8')
